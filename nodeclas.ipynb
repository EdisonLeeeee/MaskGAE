# %%
# !python train_nodeclas.py --dataset Cora --bn --l2_normalize --encoder_layers 3 --nodeclas_weight_decay 1e-4 --alpha 0.001 --lr 0.02
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.001          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Cora           |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.200          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...

# %%
# !python train_nodeclas.py --dataset Cora --bn --l2_normalize --encoder_layers 3 --nodeclas_weight_decay 1e-4 --alpha 0.004 --mask Edge --lr 0.02
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.004          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Cora           |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.200          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...

# %%
# !python train_nodeclas.py --dataset Citeseer --bn --l2_normalize --nodeclas_weight_decay 1 --alpha 0.008 --decoder_dropout 0.3
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.008          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Citeseer       |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.300          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...

# %%
# !python train_nodeclas.py --dataset Citeseer  --mask Edge --alpha 0.01 --bn --l2_normalize --decoder_channels 128 --decoder_dropout 0.5 --decoder_layers 3  \
                                              --drop_edge_p 0.7 --encoder_activation elu --encoder_channels 512 --encoder_dropout 0.7 --encoder_layers 2 \
                                              --hidden_channels 64 --lr 0.02 --nodeclas_weight_decay 5e-4 --weight_decay 5e-5
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.010          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Citeseer       |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 128            |
# +-----------------------+----------------+
# | decoder_dropout       | 0.500          |
# +-----------------------+----------------+
# | decoder_layers        | 3              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...

# %%
# !python train_nodeclas.py --dataset Pubmed --bn --l2_normalize --decoder_dropout 0.5 --nodeclas_weight_decay 1e-4 --alpha 0.001 --epochs 300 --hidden_channels 128
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.001          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Pubmed         |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.500          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...

# %%
# !python train_nodeclas.py --dataset Pubmed --bn --l2_normalize  --decoder_dropout 0.5 --hidden_channels 64 --nodeclas_weight_decay 1e-4 --alpha 0.001 --mask Edge --epochs 300
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.001          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Pubmed         |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.500          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...

# %%
# !python train_nodeclas.py --dataset Photo --bn --nodeclas_weight_decay 5e-3 --alpha 0.0 --decoder_channels 64
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0              |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Photo          |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 64             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.200          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# +-----------------------+----------------+
# | encoder_channels      | 128            |
# ...

# %%
# !python train_nodeclas.py --dataset Photo --mask Edge --alpha 1e-3 --decoder_channels 32 --decoder_dropout 0.2 --decoder_layers 2 \
                          --encoder_activation elu --encoder_channels 64 --encoder_dropout 0.7 --encoder_layers 2 --epochs 500 --hidden_channels 256 \
                          --lr 1e-2 --nodeclas_weight_decay 5e-4 --weight_decay 5e-5
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.001          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | False          |
# +-----------------------+----------------+
# | dataset               | Photo          |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.200          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# +-----------------------+----------------+
# | encoder_channels      | 64             |
# ...

# %%
# !python train_nodeclas.py --dataset Computers --mask Path --alpha 2e-3 --bn --decoder_channels 32 --decoder_dropout 0.2 --decoder_layers 2 \
                          --encoder_activation elu --encoder_channels 128 --encoder_dropout 0.7 --encoder_layers 1 --epochs 500 --hidden_channels 128 \
                          --lr 1e-2 --nodeclas_weight_decay 5e-5 --weight_decay 5e-5
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.002          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Computers      |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.200          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# +-----------------------+----------------+
# | encoder_channels      | 128            |
# ...

# %%
# !python train_nodeclas.py --dataset Computers --mask Edge --alpha 2e-3 --bn --decoder_channels 32 --decoder_dropout 0.2 --decoder_layers 2 \
                          --encoder_activation elu --encoder_channels 128 --encoder_dropout 0.5 --encoder_layers 2 --epochs 500 --hidden_channels 256 \
                          --lr 3e-2 --nodeclas_weight_decay 5e-4 --weight_decay 1e-5
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.002          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | Computers      |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.200          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# +-----------------------+----------------+
# | encoder_channels      | 128            |
# ...

# %%
# !python train_nodeclas.py --dataset arxiv --bn --encoder_layers 3 --nodeclas_weight_decay 0. \
                          --encoder_channels 256 --hidden_channels 256 --decoder_dropout 0.3 --mask Edge
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0              |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | arxiv          |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 32             |
# +-----------------------+----------------+
# | decoder_dropout       | 0.300          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# +-----------------------+----------------+
# | encoder_channels      | 256            |
# ...

# %%
# !python train_nodeclas.py --dataset arxiv --mask Path --alpha 0.001 --bn --decoder_channels 128 --decoder_dropout 0.1 --decoder_layers 4 \
                          --encoder_activation elu --encoder_channels 512 --encoder_dropout 0.6 --encoder_layers 4 --epochs 500 \
                          --hidden_channels 256 --lr 0.001 --nodeclas_weight_decay 5e-6 --walks_per_node 1 \
                          --walk_length 6 --weight_decay 0.0001
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.001          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | arxiv          |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 128            |
# +-----------------------+----------------+
# | decoder_dropout       | 0.100          |
# +-----------------------+----------------+
# | decoder_layers        | 4              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...

# %%
# !python train_nodeclas.py --dataset mag --mask Path --alpha 0.003 --bn --decoder_channels 128 --decoder_dropout 0.2 --decoder_layers 2 \
                          --encoder_activation elu --encoder_channels 256 --encoder_dropout 0.7 --encoder_layers 2 --epochs 100 \
                          --hidden_channels 128 --lr 0.01 --nodeclas_weight_decay 1e-5 --walks_per_node 2 \
                          --walk_length 4 --weight_decay 5e-5
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0.003          |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | True           |
# +-----------------------+----------------+
# | dataset               | mag            |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 128            |
# +-----------------------+----------------+
# | decoder_dropout       | 0.200          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...

# %%
# !python train_nodeclas.py --dataset mag --mask Edge --alpha 0 --decoder_channels 128 --decoder_dropout 0.2 --decoder_layers 2 \
                          --encoder_activation elu --encoder_channels 256 --encoder_dropout 0.7 --encoder_layers 2 --epochs 100 \
                          --hidden_channels 128 --lr 0.01 --nodeclas_weight_decay 1e-5  --weight_decay 5e-5 --drop_edge_p 0.7
# Out:
# +-----------------------+----------------+
# |       Parameter       |     Value      |
# +=======================+================+
# | alpha                 | 0              |
# +-----------------------+----------------+
# | batch_size            | 65536          |
# +-----------------------+----------------+
# | bn                    | False          |
# +-----------------------+----------------+
# | dataset               | mag            |
# +-----------------------+----------------+
# | debug                 | False          |
# +-----------------------+----------------+
# | decoder_channels      | 128            |
# +-----------------------+----------------+
# | decoder_dropout       | 0.200          |
# +-----------------------+----------------+
# | decoder_layers        | 2              |
# +-----------------------+----------------+
# | drop_edge_p           | 0.700          |
# +-----------------------+----------------+
# | encoder_activation    | elu            |
# ...
