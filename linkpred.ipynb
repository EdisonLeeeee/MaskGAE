# %%
# !python train_linkpred.py --dataset Cora --mask Path --bn --encoder_activation elu --lr 1e-2 --alpha 2e-3 --encoder_channels 512 \
                          --hidden_channels 256 --decoder_channels 64 --encoder_layers 1 --decoder_layers 4 --encoder_dropout 0.8 \
                          --decoder_dropout 0.1 --weight_decay 5e-5
# Out:
# +--------------------+----------------+
# |     Parameter      |     Value      |
# +====================+================+
# | alpha              | 0.002          |
# +--------------------+----------------+
# | batch_size         | 65536          |
# +--------------------+----------------+
# | bn                 | True           |
# +--------------------+----------------+
# | dataset            | Cora           |
# +--------------------+----------------+
# | debug              | False          |
# +--------------------+----------------+
# | decoder_channels   | 64             |
# +--------------------+----------------+
# | decoder_dropout    | 0.100          |
# +--------------------+----------------+
# | decoder_layers     | 4              |
# +--------------------+----------------+
# | encoder_activation | elu            |
# +--------------------+----------------+
# | encoder_channels   | 512            |
# +--------------------+----------------+
# ...

# %%
# !python train_linkpred.py --dataset Cora --mask Edge --lr 1e-2 --alpha 5e-3 --encoder_channels 256 --hidden_channels 256 \
                          --decoder_channels 128 --encoder_layers 1 --decoder_layers 2 --encoder_dropout 0.7 --decoder_dropout 0.3 \
                          --weight_decay 5e-5
# Out:
# +--------------------+----------------+
# |     Parameter      |     Value      |
# +====================+================+
# | alpha              | 0.005          |
# +--------------------+----------------+
# | batch_size         | 65536          |
# +--------------------+----------------+
# | bn                 | False          |
# +--------------------+----------------+
# | dataset            | Cora           |
# +--------------------+----------------+
# | debug              | False          |
# +--------------------+----------------+
# | decoder_channels   | 128            |
# +--------------------+----------------+
# | decoder_dropout    | 0.300          |
# +--------------------+----------------+
# | decoder_layers     | 2              |
# +--------------------+----------------+
# | encoder_activation | elu            |
# +--------------------+----------------+
# | encoder_channels   | 256            |
# +--------------------+----------------+
# ...

# %%
# !python train_linkpred.py --dataset Citeseer --mask Path --bn --encoder_activation elu --lr 1e-2 --alpha 2e-3 --encoder_channels 512 \
                          --hidden_channels 512 --decoder_channels 32  --encoder_layers 1 --decoder_layers 4 --encoder_dropout 0.8 \
                          --decoder_dropout 0.3 --weight_decay 5e-5
# Out:
# +--------------------+----------------+
# |     Parameter      |     Value      |
# +====================+================+
# | alpha              | 0.002          |
# +--------------------+----------------+
# | batch_size         | 65536          |
# +--------------------+----------------+
# | bn                 | True           |
# +--------------------+----------------+
# | dataset            | Citeseer       |
# +--------------------+----------------+
# | debug              | False          |
# +--------------------+----------------+
# | decoder_channels   | 32             |
# +--------------------+----------------+
# | decoder_dropout    | 0.300          |
# +--------------------+----------------+
# | decoder_layers     | 4              |
# +--------------------+----------------+
# | encoder_activation | elu            |
# +--------------------+----------------+
# | encoder_channels   | 512            |
# +--------------------+----------------+
# ...

# %%
# !python train_linkpred.py --dataset Citeseer --mask Edge --bn --encoder_activation elu --lr 1e-2 --alpha 1e-3 --encoder_channels 512 \
                          --hidden_channels 512 --decoder_channels 128 --encoder_layers 1 --decoder_layers 5 --encoder_dropout 0.7 \
                          --decoder_dropout 0.5 --weight_decay 1e-5
# Out:
# +--------------------+----------------+
# |     Parameter      |     Value      |
# +====================+================+
# | alpha              | 0.001          |
# +--------------------+----------------+
# | batch_size         | 65536          |
# +--------------------+----------------+
# | bn                 | True           |
# +--------------------+----------------+
# | dataset            | Citeseer       |
# +--------------------+----------------+
# | debug              | False          |
# +--------------------+----------------+
# | decoder_channels   | 128            |
# +--------------------+----------------+
# | decoder_dropout    | 0.500          |
# +--------------------+----------------+
# | decoder_layers     | 5              |
# +--------------------+----------------+
# | encoder_activation | elu            |
# +--------------------+----------------+
# | encoder_channels   | 512            |
# +--------------------+----------------+
# ...

# %%
# !python train_linkpred.py --dataset Pubmed --mask Path --bn --encoder_activation elu --lr 2e-2 --alpha 3e-3 --encoder_channels 512 \
                          --hidden_channels 256 --decoder_channels 128 --encoder_layers 2 --decoder_layers 2 --encoder_dropout 0.2 \
                          --decoder_dropout 0.2 --weight_decay 5e-5
# Out:
# +--------------------+----------------+
# |     Parameter      |     Value      |
# +====================+================+
# | alpha              | 0.003          |
# +--------------------+----------------+
# | batch_size         | 65536          |
# +--------------------+----------------+
# | bn                 | True           |
# +--------------------+----------------+
# | dataset            | Pubmed         |
# +--------------------+----------------+
# | debug              | False          |
# +--------------------+----------------+
# | decoder_channels   | 128            |
# +--------------------+----------------+
# | decoder_dropout    | 0.200          |
# +--------------------+----------------+
# | decoder_layers     | 2              |
# +--------------------+----------------+
# | encoder_activation | elu            |
# +--------------------+----------------+
# | encoder_channels   | 512            |
# +--------------------+----------------+
# ...

# %%
# !python train_linkpred.py --dataset Pubmed --mask Edge --bn --encoder_activation elu --lr 2e-2 --alpha 2e-3 --encoder_channels 512 \
                          --hidden_channels 512 --decoder_channels 64  --encoder_layers 2 --decoder_layers 3 --encoder_dropout 0. \
                          --decoder_dropout 0.4 --weight_decay 1e-5
# Out:
# +--------------------+----------------+
# |     Parameter      |     Value      |
# +====================+================+
# | alpha              | 0.002          |
# +--------------------+----------------+
# | batch_size         | 65536          |
# +--------------------+----------------+
# | bn                 | True           |
# +--------------------+----------------+
# | dataset            | Pubmed         |
# +--------------------+----------------+
# | debug              | False          |
# +--------------------+----------------+
# | decoder_channels   | 64             |
# +--------------------+----------------+
# | decoder_dropout    | 0.400          |
# +--------------------+----------------+
# | decoder_layers     | 3              |
# +--------------------+----------------+
# | encoder_activation | elu            |
# +--------------------+----------------+
# | encoder_channels   | 512            |
# +--------------------+----------------+
# ...
